# %%
import pandas as pd

pathSynonym =  input("Enter path to synonym.cvs file: ")
synonym = pd.read_csv(pathSynonym)
synonymSet = synonym.to_numpy()

#please run the command "pip install fasttext-wheel" in your termianl to install the library
import fasttext
import fasttext.util

# %%
# Task 1

import logging
import gensim.downloader as api
import random

# load word2vec-google-news-300 model
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
word2vec_googleNews300 = api.load('word2vec-google-news-300')

pairs = []

for word in synonymSet:
    synonymWord = []
    for i in range(4):
        synonymWord.append((word[0], word[i + 2], word[1]))
    pairs.append(synonymWord)

similarityGoogleNews300 = []

# use cosine similarity to find closest synonym to question from 4 given options
# store question, answer, synonym found by cosine similarity in similarityGoogleNews300
for setOfWords in pairs:
    word2vec_Similarity = {}
    choices = []
    for w1, w2, w3 in setOfWords:
        choices.append(w2)
        try:
            w1_in_w2v = word2vec_googleNews300[w1]
        except KeyError:
            break
        try:
            w2_in_w2v = word2vec_googleNews300[w2]
        except KeyError:
            break
        word2vec_Similarity[word2vec_googleNews300.similarity(w1, w2)] = w1, w2
    # if guesses could be done by cosine similarity
    # store closest synonym found in similarityGoogleNews300
    if (len(word2vec_Similarity) != 0):
        similarityGoogleNews300.append((word2vec_Similarity[max(word2vec_Similarity)][0], setOfWords[0][2], word2vec_Similarity[max(word2vec_Similarity)][1]))
     # if no guesses could be done with cosine similarity
    else:
        similarityGoogleNews300.append((setOfWords[0][0], setOfWords[0][2], random.choice(choices), "guess"))

# similarity results for each question
fileGoogleNews300 = open("word2vec-google-news-300-details.csv", "a")
fileGoogleNews300.write("question,answer,guess,label\n")

correct_labels = 0
guess_label = 0

for guesses in similarityGoogleNews300:
    if len(guesses) == 3:
        if guesses[1] == guesses[2]:
            fileGoogleNews300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},correct\n")
            correct_labels += 1
        if guesses[1] != guesses[2]:
            fileGoogleNews300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},wrong\n")
    else:
        fileGoogleNews300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},guess\n")
        guess_label += 1
fileGoogleNews300.close()        

# single line: model name, number of unique words in vocabulary, number of correct labels (C), number of questions answered (V = 80 - guess labels), C / v
fileAnalysis = open("analysis.csv", "a")
fileAnalysis.write("ModelName, VocabSize, CorrectLabel, WordNotGuessed, Accuracy \n")
fileAnalysis.write(f"word2vec-google-news-300,{len(word2vec_googleNews300)},{correct_labels},{80 - guess_label},{correct_labels / (80 - guess_label)}\n")
fileAnalysis.close()
# Out:
# 2024-02-13 07:46:14,901 : INFO : loading projection weights from C:\Users\bws98/gensim-data\word2vec-google-news-300\word2vec-google-news-300.gz
# 2024-02-13 07:46:59,335 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (3000000, 300) matrix of type float32 from C:\\Users\\bws98/gensim-data\\word2vec-google-news-300\\word2vec-google-news-300.gz', 'binary': True, 'encoding': 'utf8', 'datetime': '2024-02-13T07:46:59.335477', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'load_word2vec_format'}

# %%
#task 2 
#2 new models from different corpora but same embedding size

#first model is Wikipedia pre-trained Word2Vec
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
glove_wikigigaword300 = api.load("glove-wiki-gigaword-300")
similarityGlovewikipedia300 = []

# use cosine similarity to find closest synonym to question from 4 given options
# store question, answer, synonym found by cosine similarity in similarityGoogleNews300
for setOfWords in pairs:
    word2vec_Similarity = {}
    choices = []
    for w1, w2, w3 in setOfWords:
        choices.append(w2)
        try:
            w1_in_w2v = glove_wikigigaword300[w1]
        except KeyError:
            break
        try:
            w2_in_w2v = glove_wikigigaword300[w2]
        except KeyError:
            break
        word2vec_Similarity[glove_wikigigaword300.similarity(w1, w2)] = w1, w2
    # if guesses could be done by cosine similarity
    # store closest synonym found in similarityGoogleNews300
    if (len(word2vec_Similarity) != 0):
        similarityGlovewikipedia300.append((word2vec_Similarity[max(word2vec_Similarity)][0], setOfWords[0][2], word2vec_Similarity[max(word2vec_Similarity)][1]))
     # if no guesses could be done with cosine similarity
    else:
        similarityGlovewikipedia300.append((setOfWords[0][0], setOfWords[0][2], random.choice(choices), "guess"))

# similarity results for each question
fileGlovewWikiGigaword300= open("glove-wiki-gigaword-300-details.csv", "a")
fileGlovewWikiGigaword300.write("question,answer,guess,label\n")

correct_labels = 0
guess_label = 0

for guesses in similarityGlovewikipedia300:
    if len(guesses) == 3:
        if guesses[1] == guesses[2]:
            fileGlovewWikiGigaword300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},correct\n")
            correct_labels += 1
        if guesses[1] != guesses[2]:
            fileGlovewWikiGigaword300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},wrong\n")
    else:
        fileGlovewWikiGigaword300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},guess\n")
        guess_label += 1
fileGlovewWikiGigaword300.close()        

# single line: model name, number of unique words in vocabulary, number of correct labels (C), number of questions answered (V = 80 - guess labels), C / v
fileAnalysis = open("analysis.csv", "a")
fileAnalysis.write(f"word2vec-wiki-gigaword-300,{len(glove_wikigigaword300)},{correct_labels},{80 - guess_label},{correct_labels / (80 - guess_label)}\n")
fileAnalysis.close()
# Out:
# 2024-02-13 07:46:59,471 : INFO : loading projection weights from C:\Users\bws98/gensim-data\glove-wiki-gigaword-300\glove-wiki-gigaword-300.gz
# 2024-02-13 07:48:29,547 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (400000, 300) matrix of type float32 from C:\\Users\\bws98/gensim-data\\glove-wiki-gigaword-300\\glove-wiki-gigaword-300.gz', 'binary': False, 'encoding': 'utf8', 'datetime': '2024-02-13T07:48:29.547472', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'load_word2vec_format'}

# %%
#second model

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#fasttext.util.download_model('en', if_exists='ignore')  # English
#fastText300 = fasttext.load_model('cc.en.300.bin')
fastText300 = api.load("fasttext-wiki-news-subwords-300")
similarity_fastText300 = []

# use cosine similarity to find closest synonym to question from 4 given options
# store question, answer, synonym found by cosine similarity in similarityGoogleNews300
for setOfWords in pairs:
    word2vec_Similarity = {}
    choices = []
    for w1, w2, w3 in setOfWords:
        choices.append(w2)
        try:
            w1_in_w2v = fastText300[w1]
        except KeyError:
            break
        try:
            w2_in_w2v = fastText300[w2]
        except KeyError:
            break
        word2vec_Similarity[fastText300.similarity(w1, w2)] = w1, w2
    # if guesses could be done by cosine similarity
    # store closest synonym found in similarityGoogleNews300
    if (len(word2vec_Similarity) != 0):
        similarity_fastText300.append((word2vec_Similarity[max(word2vec_Similarity)][0], setOfWords[0][2], word2vec_Similarity[max(word2vec_Similarity)][1]))
     # if no guesses could be done with cosine similarity
    else:
        similarity_fastText300.append((setOfWords[0][0], setOfWords[0][2], random.choice(choices), "guess"))

# similarity results for each question
fileFastText300 = open("FastText-wiki-300-details.csv", "a")
fileFastText300.write("question,answer,guess,label\n")

correct_labels = 0
guess_label = 0

for guesses in similarity_fastText300:
    if len(guesses) == 3:
        if guesses[1] == guesses[2]:
            fileFastText300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},correct\n")
            correct_labels += 1
        if guesses[1] != guesses[2]:
            fileFastText300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},wrong\n")
    else:
        fileFastText300.write(f"{guesses[0]},{guesses[1]},{guesses[2]},guess\n")
        guess_label += 1
fileFastText300.close()        

# single line: model name, number of unique words in vocabulary, number of correct labels (C), number of questions answered (V = 80 - guess labels), C / v
fileAnalysis = open("analysis.csv", "a")
print(guess_label)
fileAnalysis.write(f"FastText-wiki-300,{len(fastText300)},{correct_labels},{80 - guess_label},{correct_labels / (80 - guess_label)}\n")
fileAnalysis.close()
# Out:
# 2024-02-13 07:48:29,659 : INFO : loading projection weights from C:\Users\bws98/gensim-data\fasttext-wiki-news-subwords-300\fasttext-wiki-news-subwords-300.gz
# 2024-02-13 07:52:24,080 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (999999, 300) matrix of type float32 from C:\\Users\\bws98/gensim-data\\fasttext-wiki-news-subwords-300\\fasttext-wiki-news-subwords-300.gz', 'binary': False, 'encoding': 'utf8', 'datetime': '2024-02-13T07:52:24.080446', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'load_word2vec_format'}
# 0

# %%
#task 2 
#2 new models from the same corpus but different embedding sizes

# first model is Glove Twitter model
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
glove_twitter100 = api.load("glove-twitter-100")

similarityGloveTwitter100 = []

# use cosine similarity to find closest synonym to question from 4 given options
# store question, answer, synonym found by cosine similarity in similarityGoogleNews300
for setOfWords in pairs:
    word2vec_Similarity = {}
    choices = []
    for w1, w2, w3 in setOfWords:
        choices.append(w2)
        try:
            w1_in_w2v = glove_twitter100[w1]
        except KeyError:
            break
        try:
            w2_in_w2v = glove_twitter100[w2]
        except KeyError:
            break
        word2vec_Similarity[glove_twitter100.similarity(w1, w2)] = w1, w2
    # if guesses could be done by cosine similarity
    # store closest synonym found in similarityGoogleNews300
    if (len(word2vec_Similarity) != 0):
        similarityGloveTwitter100.append((word2vec_Similarity[max(word2vec_Similarity)][0], setOfWords[0][2], word2vec_Similarity[max(word2vec_Similarity)][1]))
     # if no guesses could be done with cosine similarity
    else:
        similarityGloveTwitter100.append((setOfWords[0][0], setOfWords[0][2], random.choice(choices), "guess"))

# similarity results for each question
fileGloveTwitter100 = open("glove-twitter-100-details.csv", "a")
fileGloveTwitter100.write("question,answer,guess,label\n")

correct_labels = 0
guess_label = 0

for guesses in similarityGloveTwitter100:
    if len(guesses) == 3:
        if guesses[1] == guesses[2]:
            fileGloveTwitter100.write(f"{guesses[0]},{guesses[1]},{guesses[2]},correct\n")
            correct_labels += 1
        if guesses[1] != guesses[2]:
            fileGloveTwitter100.write(f"{guesses[0]},{guesses[1]},{guesses[2]},wrong\n")
    else:
        fileGloveTwitter100.write(f"{guesses[0]},{guesses[1]},{guesses[2]},guess\n")
        guess_label += 1
fileGloveTwitter100.close()        

# single line: model name, number of unique words in vocabulary, number of correct labels (C), number of questions answered (V = 80 - guess labels), C / v
fileAnalysis = open("analysis.csv", "a")
fileAnalysis.write(f"word2vec-glove-twitter-100,{len(glove_twitter100)},{correct_labels},{80 - guess_label},{correct_labels / (80 - guess_label)}\n")
fileAnalysis.close()



# fourth model same copora but different embedding size
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
glove_twitter25 = api.load("glove-twitter-25")

similarityGloveTwitter25 = []

# use cosine similarity to find closest synonym to question from 4 given options
# store question, answer, synonym found by cosine similarity in similarityGoogleNews300
for setOfWords in pairs:
    word2vec_Similarity = {}
    choices = []
    for w1, w2, w3 in setOfWords:
        choices.append(w2)
        try:
            w1_in_w2v = glove_twitter25[w1]
        except KeyError:
            break
        try:
            w2_in_w2v = glove_twitter25[w2]
        except KeyError:
            break
        word2vec_Similarity[glove_twitter25.similarity(w1, w2)] = w1, w2
    # if guesses could be done by cosine similarity
    # store closest synonym found in similarityGoogleNews300
    if (len(word2vec_Similarity) != 0):
        similarityGloveTwitter25.append((word2vec_Similarity[max(word2vec_Similarity)][0], setOfWords[0][2], word2vec_Similarity[max(word2vec_Similarity)][1]))
     # if no guesses could be done with cosine similarity
    else:
        similarityGloveTwitter25.append((setOfWords[0][0], setOfWords[0][2], random.choice(choices), "guess"))

# similarity results for each question
fileGloveTwitter25 = open("glove-twitter-25-details.csv", "a")
fileGloveTwitter25.write("question,answer,guess,label\n")

correct_labels = 0
guess_label = 0

for guesses in similarityGloveTwitter25:
    if len(guesses) == 3:
        if guesses[1] == guesses[2]:
            fileGloveTwitter25.write(f"{guesses[0]},{guesses[1]},{guesses[2]},correct\n")
            correct_labels += 1
        if guesses[1] != guesses[2]:
            fileGloveTwitter25.write(f"{guesses[0]},{guesses[1]},{guesses[2]},wrong\n")
    else:
        fileGloveTwitter25.write(f"{guesses[0]},{guesses[1]},{guesses[2]},guess\n")
        guess_label += 1
fileGloveTwitter25.close()        

# single line: model name, number of unique words in vocabulary, number of correct labels (C), number of questions answered (V = 80 - guess labels), C / v
fileAnalysis = open("analysis.csv", "a")
fileAnalysis.write(f"glove-twitter-25,{len(glove_twitter25)},{correct_labels},{80 - guess_label},{correct_labels / (80 - guess_label)}\n")
fileAnalysis.close()
# Out:
# 2024-02-13 07:52:24,303 : INFO : loading projection weights from C:\Users\bws98/gensim-data\glove-twitter-100\glove-twitter-100.gz
# 2024-02-13 07:54:03,338 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (1193514, 100) matrix of type float32 from C:\\Users\\bws98/gensim-data\\glove-twitter-100\\glove-twitter-100.gz', 'binary': False, 'encoding': 'utf8', 'datetime': '2024-02-13T07:54:03.338437', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'load_word2vec_format'}
# 2024-02-13 07:54:03,480 : INFO : loading projection weights from C:\Users\bws98/gensim-data\glove-twitter-25\glove-twitter-25.gz
# 2024-02-13 07:54:28,810 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (1193514, 25) matrix of type float32 from C:\\Users\\bws98/gensim-data\\glove-twitter-25\\glove-twitter-25.gz', 'binary': False, 'encoding': 'utf8', 'datetime': '2024-02-13T07:54:28.810403', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'load_word2vec_format'}

# %%
import matplotlib.pyplot as plt
import pandas as pd

analysis_data = pd.read_csv("analysis.csv")

analysis_data.columns = analysis_data.columns.str.strip()

plt.bar(analysis_data["ModelName"], analysis_data["Accuracy"])

average_accuracy = 88.28  # Replace this with the actual average accuracy value
plt.axhline(y=average_accuracy / 100, color='red', linestyle='--', label='human_gold_standard')

plt.title("Model Comparison")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.ylim(0, 1)  # Set the y-axis limits to better visualize differences

plt.legend()

plt.savefig('accuracy_comparison_plot_with_human_gold_standard.png')
plt.show()


plt.bar(analysis_data["ModelName"], analysis_data["Accuracy"])

random_baseline = 0.25
plt.axhline(y=random_baseline, color='red', linestyle='--', label='random_baseline')

plt.title("Model Comparison")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.ylim(0, 1)  # Set the y-axis limits to better visualize differences

plt.legend()

plt.savefig('accuracy_comparison_plot_with_random_baseline.png')
plt.show()

# %%
#Task 3
#Training my own model
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from gensim.models import Word2Vec

nltk.download('punkt')

book_files = ["book1.txt", "book2.txt", "book3.txt", "book4.txt", "book5.txt"]

sentences = []
for book in book_files:
    with open(book, "r", errors='ignore') as f:
        text = f.read()
        sent_tokens = sent_tokenize(text)
        for sentence in sent_tokens:
            word_tokens = word_tokenize(sentence)
            sentences.append(word_tokens)

models = {
    f'my_own_corpus-E{25}-W{5}': Word2Vec(sentences, window=5, vector_size=25, min_count=1),
    f'my_own_corpus-E{25}-W{10}': Word2Vec(sentences, window=10, vector_size=25, min_count=1),
    f'my_own_corpus-E{100}-W{5}': Word2Vec(sentences, window=5, vector_size=100, min_count=1),
    f'my_own_corpus-E{100}-W{10}': Word2Vec(sentences, window=10, vector_size=100, min_count=1),
}
for model_name, model in models.items():
    correct_labels = 0
    guess_label = 0
    similarity = []

    # use cosine similarity to find closest synonym to question from 4 given options
    # store question, answer, synonym found by cosine similarity in my_own_corpus
    for setOfWords in pairs:
        word2vec_Similarity = {}
        choices = []
        for w1, w2, w3 in setOfWords:
            choices.append(w2)
            try:
                w1_in_w2v = model.wv[w1]
            except KeyError:
                break
            try:
                w2_in_w2v = model.wv[w2]
            except KeyError:
                break
            word2vec_Similarity[model.wv.similarity(w1, w2)] = w1, w2
        # if guesses could be done by cosine similarity
        # store closest synonym found in my_own_corpus
        if (len(word2vec_Similarity) != 0):
            similarity.append((word2vec_Similarity[max(word2vec_Similarity)][0], setOfWords[0][2], word2vec_Similarity[max(word2vec_Similarity)][1]))
        # if no guesses could be done with cosine similarity
        # leave closest synonym as '-'
        else:
            similarity.append((setOfWords[0][0], setOfWords[0][2], random.choice(choices), "guess"))

            
    with open(f"{model_name}-details.csv", "a") as f:
        f.write("question,answer,guess,label\n")
        for guesses in similarity:
            if len(guesses) == 3:
                if guesses[1] == guesses[2]:
                    f.write(f"{guesses[0]},{guesses[1]},{guesses[2]},correct\n")
                    correct_labels += 1
                if guesses[1] != guesses[2]:
                    f.write(f"{guesses[0]},{guesses[1]},{guesses[2]},wrong\n")
            else:
                f.write(f"{guesses[0]},{guesses[1]},{guesses[2]},guess\n")
                guess_label += 1
    with open("analysis.csv", "a") as f:
        f.write(f"{model_name},{len(sentences)},{correct_labels},{80 - guess_label},{correct_labels / (80 - guess_label)}\n")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bws98\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-02-13 07:54:42,919 : INFO : collecting all words and their counts
# 2024-02-13 07:54:42,919 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-02-13 07:54:42,950 : INFO : PROGRESS: at sentence #10000, processed 216960 words, keeping 13865 word types
# 2024-02-13 07:54:42,981 : INFO : PROGRESS: at sentence #20000, processed 320419 words, keeping 18525 word types
# 2024-02-13 07:54:42,997 : INFO : PROGRESS: at sentence #30000, processed 434786 words, keeping 23082 word types
# 2024-02-13 07:54:43,013 : INFO : PROGRESS: at sentence #40000, processed 557687 words, keeping 27373 word types
# 2024-02-13 07:54:43,029 : INFO : PROGRESS: at sentence #50000, processed 678358 words, keeping 29973 word types
# 2024-02-13 07:54:43,044 : INFO : PROGRESS: at sentence #60000, processed 779161 words, keeping 32840 word types
# 2024-02-13 07:54:43,076 : INFO : PROGRESS: at sentence #70000, processed 886803 words, keeping 35149 word types
# 2024-02-13 07:54:43,092 : INFO : PROGRESS: at sentence #80000, processed 998467 words, keeping 37077 word types
# 2024-02-13 07:54:43,107 : INFO : PROGRESS: at sentence #90000, processed 1107902 words, keeping 39109 word types
# 2024-02-13 07:54:43,123 : INFO : PROGRESS: at sentence #100000, processed 1210947 words, keeping 41103 word types
# 2024-02-13 07:54:43,154 : INFO : PROGRESS: at sentence #110000, processed 1350293 words, keeping 44209 word types
# 2024-02-13 07:54:43,191 : INFO : collected 49854 word types from a corpus of 1634062 raw words and 118377 sentences
# 2024-02-13 07:54:43,201 : INFO : Creating a fresh vocabulary
# 2024-02-13 07:54:43,311 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 49854 unique words (100.00% of original 49854, drops 0)', 'datetime': '2024-02-13T07:54:43.311837', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:43,311 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1634062 word corpus (100.00% of original 1634062, drops 0)', 'datetime': '2024-02-13T07:54:43.311837', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:43,500 : INFO : deleting the raw counts dictionary of 49854 items
# 2024-02-13 07:54:43,500 : INFO : sample=0.001 downsamples 46 most-common words
# 2024-02-13 07:54:43,500 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1181615.1378943648 word corpus (72.3%% of prior 1634062)', 'datetime': '2024-02-13T07:54:43.500200', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:43,798 : INFO : estimated required memory for 49854 words and 25 dimensions: 34897800 bytes
# 2024-02-13 07:54:43,798 : INFO : resetting layer weights
# 2024-02-13 07:54:43,840 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-02-13T07:54:43.840475', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# 2024-02-13 07:54:43,840 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 49854 vocabulary and 25 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2024-02-13T07:54:43.840475', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:44,607 : INFO : EPOCH 0: training on 1634062 raw words (1181618 effective words) took 0.8s, 1546358 effective words/s
# 2024-02-13 07:54:45,376 : INFO : EPOCH 1: training on 1634062 raw words (1181763 effective words) took 0.8s, 1537536 effective words/s
# 2024-02-13 07:54:46,160 : INFO : EPOCH 2: training on 1634062 raw words (1181857 effective words) took 0.8s, 1512083 effective words/s
# 2024-02-13 07:54:46,929 : INFO : EPOCH 3: training on 1634062 raw words (1181092 effective words) took 0.8s, 1562971 effective words/s
# 2024-02-13 07:54:47,698 : INFO : EPOCH 4: training on 1634062 raw words (1182078 effective words) took 0.8s, 1531031 effective words/s
# 2024-02-13 07:54:47,698 : INFO : Word2Vec lifecycle event {'msg': 'training on 8170310 raw words (5908408 effective words) took 3.9s, 1528335 effective words/s', 'datetime': '2024-02-13T07:54:47.698147', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:47,698 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=49854, vector_size=25, alpha=0.025>', 'datetime': '2024-02-13T07:54:47.698147', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 2024-02-13 07:54:47,713 : INFO : collecting all words and their counts
# 2024-02-13 07:54:47,713 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-02-13 07:54:47,745 : INFO : PROGRESS: at sentence #10000, processed 216960 words, keeping 13865 word types
# 2024-02-13 07:54:47,761 : INFO : PROGRESS: at sentence #20000, processed 320419 words, keeping 18525 word types
# 2024-02-13 07:54:47,776 : INFO : PROGRESS: at sentence #30000, processed 434786 words, keeping 23082 word types
# 2024-02-13 07:54:47,807 : INFO : PROGRESS: at sentence #40000, processed 557687 words, keeping 27373 word types
# 2024-02-13 07:54:47,824 : INFO : PROGRESS: at sentence #50000, processed 678358 words, keeping 29973 word types
# 2024-02-13 07:54:47,839 : INFO : PROGRESS: at sentence #60000, processed 779161 words, keeping 32840 word types
# 2024-02-13 07:54:47,855 : INFO : PROGRESS: at sentence #70000, processed 886803 words, keeping 35149 word types
# 2024-02-13 07:54:47,886 : INFO : PROGRESS: at sentence #80000, processed 998467 words, keeping 37077 word types
# 2024-02-13 07:54:47,902 : INFO : PROGRESS: at sentence #90000, processed 1107902 words, keeping 39109 word types
# 2024-02-13 07:54:47,922 : INFO : PROGRESS: at sentence #100000, processed 1210947 words, keeping 41103 word types
# 2024-02-13 07:54:47,949 : INFO : PROGRESS: at sentence #110000, processed 1350293 words, keeping 44209 word types
# 2024-02-13 07:54:47,980 : INFO : collected 49854 word types from a corpus of 1634062 raw words and 118377 sentences
# 2024-02-13 07:54:47,980 : INFO : Creating a fresh vocabulary
# 2024-02-13 07:54:48,090 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 49854 unique words (100.00% of original 49854, drops 0)', 'datetime': '2024-02-13T07:54:48.090596', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:48,090 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1634062 word corpus (100.00% of original 1634062, drops 0)', 'datetime': '2024-02-13T07:54:48.090596', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:48,294 : INFO : deleting the raw counts dictionary of 49854 items
# 2024-02-13 07:54:48,294 : INFO : sample=0.001 downsamples 46 most-common words
# 2024-02-13 07:54:48,294 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1181615.1378943648 word corpus (72.3%% of prior 1634062)', 'datetime': '2024-02-13T07:54:48.294599', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:48,592 : INFO : estimated required memory for 49854 words and 25 dimensions: 34897800 bytes
# 2024-02-13 07:54:48,592 : INFO : resetting layer weights
# 2024-02-13 07:54:48,592 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-02-13T07:54:48.592751', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# 2024-02-13 07:54:48,592 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 49854 vocabulary and 25 features, using sg=0 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-02-13T07:54:48.592751', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:49,439 : INFO : EPOCH 0: training on 1634062 raw words (1181469 effective words) took 0.8s, 1404600 effective words/s
# 2024-02-13 07:54:50,301 : INFO : EPOCH 1: training on 1634062 raw words (1181886 effective words) took 0.9s, 1374353 effective words/s
# 2024-02-13 07:54:51,160 : INFO : EPOCH 2: training on 1634062 raw words (1181659 effective words) took 0.9s, 1388613 effective words/s
# 2024-02-13 07:54:52,007 : INFO : EPOCH 3: training on 1634062 raw words (1181313 effective words) took 0.8s, 1398590 effective words/s
# 2024-02-13 07:54:52,854 : INFO : EPOCH 4: training on 1634062 raw words (1181334 effective words) took 0.8s, 1400152 effective words/s
# 2024-02-13 07:54:52,854 : INFO : Word2Vec lifecycle event {'msg': 'training on 8170310 raw words (5907661 effective words) took 4.3s, 1385256 effective words/s', 'datetime': '2024-02-13T07:54:52.854610', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:52,870 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=49854, vector_size=25, alpha=0.025>', 'datetime': '2024-02-13T07:54:52.870242', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 2024-02-13 07:54:52,870 : INFO : collecting all words and their counts
# 2024-02-13 07:54:52,870 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-02-13 07:54:52,901 : INFO : PROGRESS: at sentence #10000, processed 216960 words, keeping 13865 word types
# 2024-02-13 07:54:52,917 : INFO : PROGRESS: at sentence #20000, processed 320419 words, keeping 18525 word types
# 2024-02-13 07:54:52,948 : INFO : PROGRESS: at sentence #30000, processed 434786 words, keeping 23082 word types
# 2024-02-13 07:54:52,980 : INFO : PROGRESS: at sentence #40000, processed 557687 words, keeping 27373 word types
# 2024-02-13 07:54:52,996 : INFO : PROGRESS: at sentence #50000, processed 678358 words, keeping 29973 word types
# 2024-02-13 07:54:53,011 : INFO : PROGRESS: at sentence #60000, processed 779161 words, keeping 32840 word types
# 2024-02-13 07:54:53,043 : INFO : PROGRESS: at sentence #70000, processed 886803 words, keeping 35149 word types
# 2024-02-13 07:54:53,059 : INFO : PROGRESS: at sentence #80000, processed 998467 words, keeping 37077 word types
# 2024-02-13 07:54:53,074 : INFO : PROGRESS: at sentence #90000, processed 1107902 words, keeping 39109 word types
# 2024-02-13 07:54:53,105 : INFO : PROGRESS: at sentence #100000, processed 1210947 words, keeping 41103 word types
# 2024-02-13 07:54:53,121 : INFO : PROGRESS: at sentence #110000, processed 1350293 words, keeping 44209 word types
# 2024-02-13 07:54:53,168 : INFO : collected 49854 word types from a corpus of 1634062 raw words and 118377 sentences
# 2024-02-13 07:54:53,168 : INFO : Creating a fresh vocabulary
# 2024-02-13 07:54:53,278 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 49854 unique words (100.00% of original 49854, drops 0)', 'datetime': '2024-02-13T07:54:53.278535', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:53,278 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1634062 word corpus (100.00% of original 1634062, drops 0)', 'datetime': '2024-02-13T07:54:53.278535', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:53,466 : INFO : deleting the raw counts dictionary of 49854 items
# 2024-02-13 07:54:53,466 : INFO : sample=0.001 downsamples 46 most-common words
# 2024-02-13 07:54:53,466 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1181615.1378943648 word corpus (72.3%% of prior 1634062)', 'datetime': '2024-02-13T07:54:53.466965', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:53,765 : INFO : estimated required memory for 49854 words and 100 dimensions: 64810200 bytes
# 2024-02-13 07:54:53,765 : INFO : resetting layer weights
# 2024-02-13 07:54:53,780 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-02-13T07:54:53.780800', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# 2024-02-13 07:54:53,780 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 49854 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2024-02-13T07:54:53.780800', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:54,581 : INFO : EPOCH 0: training on 1634062 raw words (1181635 effective words) took 0.8s, 1489639 effective words/s
# 2024-02-13 07:54:55,381 : INFO : EPOCH 1: training on 1634062 raw words (1181173 effective words) took 0.8s, 1499966 effective words/s
# 2024-02-13 07:54:56,166 : INFO : EPOCH 2: training on 1634062 raw words (1180686 effective words) took 0.8s, 1506914 effective words/s
# 2024-02-13 07:54:56,951 : INFO : EPOCH 3: training on 1634062 raw words (1181987 effective words) took 0.8s, 1506446 effective words/s
# 2024-02-13 07:54:57,750 : INFO : EPOCH 4: training on 1634062 raw words (1182192 effective words) took 0.8s, 1485594 effective words/s
# 2024-02-13 07:54:57,766 : INFO : Word2Vec lifecycle event {'msg': 'training on 8170310 raw words (5907673 effective words) took 4.0s, 1487046 effective words/s', 'datetime': '2024-02-13T07:54:57.766322', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:57,766 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=49854, vector_size=100, alpha=0.025>', 'datetime': '2024-02-13T07:54:57.766322', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 2024-02-13 07:54:57,766 : INFO : collecting all words and their counts
# 2024-02-13 07:54:57,766 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-02-13 07:54:57,797 : INFO : PROGRESS: at sentence #10000, processed 216960 words, keeping 13865 word types
# 2024-02-13 07:54:57,813 : INFO : PROGRESS: at sentence #20000, processed 320419 words, keeping 18525 word types
# 2024-02-13 07:54:57,842 : INFO : PROGRESS: at sentence #30000, processed 434786 words, keeping 23082 word types
# 2024-02-13 07:54:57,860 : INFO : PROGRESS: at sentence #40000, processed 557687 words, keeping 27373 word types
# 2024-02-13 07:54:57,876 : INFO : PROGRESS: at sentence #50000, processed 678358 words, keeping 29973 word types
# 2024-02-13 07:54:57,891 : INFO : PROGRESS: at sentence #60000, processed 779161 words, keeping 32840 word types
# 2024-02-13 07:54:57,907 : INFO : PROGRESS: at sentence #70000, processed 886803 words, keeping 35149 word types
# 2024-02-13 07:54:57,922 : INFO : PROGRESS: at sentence #80000, processed 998467 words, keeping 37077 word types
# 2024-02-13 07:54:57,942 : INFO : PROGRESS: at sentence #90000, processed 1107902 words, keeping 39109 word types
# 2024-02-13 07:54:57,970 : INFO : PROGRESS: at sentence #100000, processed 1210947 words, keeping 41103 word types
# 2024-02-13 07:54:57,985 : INFO : PROGRESS: at sentence #110000, processed 1350293 words, keeping 44209 word types
# 2024-02-13 07:54:58,032 : INFO : collected 49854 word types from a corpus of 1634062 raw words and 118377 sentences
# 2024-02-13 07:54:58,032 : INFO : Creating a fresh vocabulary
# 2024-02-13 07:54:58,143 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 49854 unique words (100.00% of original 49854, drops 0)', 'datetime': '2024-02-13T07:54:58.143167', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:58,143 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1634062 word corpus (100.00% of original 1634062, drops 0)', 'datetime': '2024-02-13T07:54:58.143167', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:58,331 : INFO : deleting the raw counts dictionary of 49854 items
# 2024-02-13 07:54:58,331 : INFO : sample=0.001 downsamples 46 most-common words
# 2024-02-13 07:54:58,331 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1181615.1378943648 word corpus (72.3%% of prior 1634062)', 'datetime': '2024-02-13T07:54:58.331050', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-02-13 07:54:58,645 : INFO : estimated required memory for 49854 words and 100 dimensions: 64810200 bytes
# 2024-02-13 07:54:58,645 : INFO : resetting layer weights
# 2024-02-13 07:54:58,661 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-02-13T07:54:58.661018', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# 2024-02-13 07:54:58,661 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 49854 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-02-13T07:54:58.661018', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:54:59,523 : INFO : EPOCH 0: training on 1634062 raw words (1180768 effective words) took 0.9s, 1366645 effective words/s
# 2024-02-13 07:55:00,386 : INFO : EPOCH 1: training on 1634062 raw words (1182079 effective words) took 0.9s, 1379225 effective words/s
# 2024-02-13 07:55:01,263 : INFO : EPOCH 2: training on 1634062 raw words (1181490 effective words) took 0.9s, 1362697 effective words/s
# 2024-02-13 07:55:02,126 : INFO : EPOCH 3: training on 1634062 raw words (1181813 effective words) took 0.9s, 1368253 effective words/s
# 2024-02-13 07:55:02,989 : INFO : EPOCH 4: training on 1634062 raw words (1181449 effective words) took 0.9s, 1386019 effective words/s
# 2024-02-13 07:55:02,989 : INFO : Word2Vec lifecycle event {'msg': 'training on 8170310 raw words (5907599 effective words) took 4.3s, 1365602 effective words/s', 'datetime': '2024-02-13T07:55:02.989885', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-02-13 07:55:02,989 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=49854, vector_size=100, alpha=0.025>', 'datetime': '2024-02-13T07:55:02.989885', 'gensim': '4.3.2', 'python': '3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
